# %% [markdown]
# <a href="https://colab.research.google.com/github/josemiki/CS2016/blob/master/Faster_R_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import shutil
import zipfile
import urllib
import xml.etree.ElementTree as ET
import numpy as np
import csv
import pandas
from google.colab import drive
from google.colab import files
#from zipfile import ZipFile

DATASET_DRIVEID = '1smy3akpEuntfS6NY-XCyjgv4BARW3C_g'

DATASET_DIR = 'dataset'
ANNOTATIONS_FILE = 'annotations.csv'
CLASSES_FILE = 'classes.csv'



drive_url = 'https://drive.google.com/uc?export=download&id=' + DATASET_DRIVEID
file_name = 'data' + '.rar'

urllib.request.urlretrieve(drive_url,file_name)
print('Download completed!')
# Out:
# Download completed!

# %%
cd frcnn-from-scratch-with-keras/
# Out:
# /content/frcnn-from-scratch-with-keras

# %%
# !git clone https://github.com/kentaroy47/frcnn-from-scratch-with-keras.git
#cd frcnn-from-scratch-with-keras/
#cd frcnn-from-scratch-with-keras/
# Out:
# fatal: destination path 'frcnn-from-scratch-with-keras' already exists and is not an empty directory.

# %%
#!git clone https://github.com/kentaroy47/frcnn-from-scratch-with-keras.git
#!cd frcnn-from-scratch-with-keras/
#!pip install -r requirements.txt

#!python train_rpn.py --network vgg -o simple -p train.txt

import os
import shutil
import zipfile
import urllib
import xml.etree.ElementTree as ET
import numpy as np
import csv
import pandas
from google.colab import drive
from google.colab import files
#from zipfile import ZipFile

DATASET_DRIVEID = '1D_RZhVzkyBUVnFRijd5ozhlfpkIeeyEV'

DATASET_DIR = 'dataset'
ANNOTATIONS_FILE = 'annotations.csv'
CLASSES_FILE = 'classes.csv'



drive_url = 'https://drive.google.com/uc?export=download&id=' + DATASET_DRIVEID
file_name = 'train' + '.txt'

urllib.request.urlretrieve(drive_url,file_name)
print('Download completed!')
# Out:
# Download completed!

# %%
import os
import shutil
import zipfile
import urllib
import xml.etree.ElementTree as ET
import numpy as np
import csv
import pandas
from google.colab import drive
from google.colab import files
#from zipfile import ZipFile

#DATASET_DRIVEID = '1AiXJZGu4pmJqwplE9thHFqfie0HWjEse'
DATASET_DRIVEID = '1Rw3yMc_W5IeDiJ-HMiTT54ywIPlVy0Or'
DATASET_DIR = 'dataset'
ANNOTATIONS_FILE = 'annotations.csv'
CLASSES_FILE = 'classes.csv'



drive_url = 'https://drive.google.com/uc?export=download&id=' + DATASET_DRIVEID
#file_name = 'rpn.vgg.weights.48-1.23' + '.hdf5'
file_name = 'requirements' + '.txt'

urllib.request.urlretrieve(drive_url,file_name)
print('Download completed!')
# Out:
# Download completed!

# %%
# !pip install -r requirements.txt

# %%
# !unrar x data.rar
# Out:
# UNRAR 5.50 freeware      Copyright (c) 1993-2017 Alexander Roshal
#
#
# Extracting from data.rar
#
# Creating    armasDB                                                   OK
#   OK
#   OK
# Creating    armasDB/Imagen                                            OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# ...

# %%
mv armasDB/Imagen/ armasDB/imagen/

# %%
cd ..
#!python train_frcnn.py --network vgg --rpn rpn.vgg.weights.48-1.23.hdf5 --elen 5 -o simple -p train.txt
#!python train_rpn.py --network vgg -o simple -p train.txt

# %%
mv pretrian/ pretrain

# %%
# !python train_frcnn.py --network vgg --rpn rpn.vgg.weights.48-1.23.hdf5 --elen 5 -o simple -p train.txt
# Out:
# Using TensorFlow backend.
# WARNING: Logging before flag parsing goes to stderr.
# W0813 18:44:06.451360 140012830345088 deprecation_wrapper.py:119] From train_frcnn.py:23: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0813 18:44:06.451697 140012830345088 deprecation_wrapper.py:119] From train_frcnn.py:25: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2019-08-13 18:44:06.457188: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2019-08-13 18:44:06.457380: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1567dc0 executing computations on platform Host. Devices:
# 2019-08-13 18:44:06.457408: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-08-13 18:44:06.459277: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcuda.so.1
# ...

# %%
# !pip install -r requirements.txt
